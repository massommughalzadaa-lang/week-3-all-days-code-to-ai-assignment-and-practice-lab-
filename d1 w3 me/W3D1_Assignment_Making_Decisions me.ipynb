# %% [markdown]
# # Week 3 · Day 1 — Assignment
# ### Code to AI — Python & Data Science
#
# Complete this assignment **before the next class** and push it to your GitHub repo. Post the repo link in the WhatsApp group. ✅
#
# **Rule:** use only what we learned in Day 1 (`if` / `elif` / `else`, `and`, `or`, `not`, `in`). No loops yet — those are tomorrow!

# %% [markdown]
# ## Task 1 — BMI Category Checker
#
# Create two variables `weight` (in kg) and `height` (in meters), for example `weight = 70` and `height = 1.75`.
#
# 1. Calculate BMI using the formula: `bmi = weight / (height ** 2)`
# 2. Print the BMI value
# 3. Print the category based on BMI:
#    - Below 18.5 → `"Underweight"`
#    - 18.5 to 24.9 → `"Normal"`
#    - 25 to 29.9 → `"Overweight"`
#    - 30 and above → `"Obese"`

# %%
# Your code here
weight = 70
height = 1.75

bmi = weight / (height ** 2)

print("BMI:", bmi)

if bmi < 18.5:
    print("Category: Underweight")
elif bmi < 25:
    print("Category: Normal")
elif bmi < 30:
    print("Category: Overweight")
else:
    print("category: Obese")
# Out:
# BMI: 22.857142857142858
# Category: Normal

# %% [markdown]
# ## Task 2 — Simple Calculator with Decision
#
# Create three variables: `a = 10`, `b = 0`, and `operation = "divide"`.
#
# Based on `operation`, perform and print the result:
# - `"add"` → a + b
# - `"subtract"` → a - b
# - `"multiply"` → a * b
# - `"divide"` → a / b **but** first check: if `b == 0`, print `"Cannot divide by zero!"` instead
# - anything else → print `"Unknown operation"`

# %%
# Your code here
a = 10
b = 0
operation = "divide"

if operation == "add":
    print(a + b)
elif operation == "subtract":
    print(a - b)
elif operation == "multiply":
    print(a * b)
elif operation == "divide":
    if b == 0:
        print("Cannot divide by zero!")
    else:
        print(a / b)
else:
    print("Unknown operation")
# Out:
# Cannot divide by zero!

# %% [markdown]
# ## Task 3 — Password Strength Checker (stretch)
#
# Given a variable `password = "Ali123"`, check and print whether it is strong.
#
# A password is **strong** if BOTH:
# - its length is at least 6 characters (`len(password) >= 6`), AND
# - it is not one of the common weak passwords in this list: `["123456", "password", "12345678", "qwerty"]`
#
# Print `"Strong password ✅"` or `"Weak password ❌"` accordingly.
#
# *Hint: combine `len(...)` with `and` and `not ... in ...`.*

# %%
# Your code here
password = "A11123"

weak_passwords = ["123456", "password", "12345678", "qwerty"]

if len(password) >= 6 and password not in weak_passwords:
    print("Strong password ✅")
else:
    print("Weak password ❌")
# Out:
# Strong password ✅

# %% [markdown]
# ---
# ### Submission checklist
# - [ ] All three tasks attempted
# - [ ] Code runs without errors
# - [ ] Notebook saved and pushed to your GitHub repo
# - [ ] Repo link posted in the WhatsApp group
#
# You've got this! 🚀
